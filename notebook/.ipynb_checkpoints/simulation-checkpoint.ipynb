# %%
import sys
sys.path.append("/Users/manon/ztf_stage/python") #directory to your python class
sys.path.append("/Users/manon/ztf_stage/script") #directory to your python script
sys.path.append("/Users/manon/ztf_stage/csv") #directory to your csv file
sys.path.append("/Users/manon/ZTF/data") #directory to your data (from simsurvey)
sys.path.append("/Users/manon/ZTF") #directory to simsurvey_tools.py

# %%
import os
from ztf_hdf5 import Read_LightCurve

# %%
home_dir = os.environ.get('HOME')
script_dir = os.path.join(home_dir, 'ztf_stage/script/run_simulation.py')
script_dir
# Out:
# '/Users/manon/ztf_stage/script/run_simulation.py'

# %%
# To have information about the python script parameters
# !python /Users/manon/ztf_stage/script/run_simulation.py --help
# Out:
# Usage: run_simulation.py [options]
#
# Options:
#   -h, --help            show this help message and exit
#   --folder_dir=FOLDER_DIR
#                         folder directory [data]
#   --sfd98File=SFD98FILE
#                         sfd98 file name [sfd98]
#   --rcidFile=RCIDFILE   rcid file name [ZTF_corners_rcid.txt]
#   --csvFile=CSVFILE     csv file name for observation
#                         [2018_all_logs_from_dr1_rcid_zp_from_masci.csv]
#   --ZTF_Fields=ZTF_FIELDS
#                         ZTF field file name for observation [ZTF_Fields.txt]
#   --DataFileName=DATAFILENAME
#                         Data file name [Data.hdf5]
#   --MetaFileName=METAFILENAME
#                         Meta data file name [Meta.hdf5]
#   --outputDir=OUTPUTDIR
#                         output directory [dataLC]
#   --path_prefix=PATH_PREFIX
#                         path prefix for hdf5 [SN]
#   --zmin=ZMIN           min redshift [0.01]
#   --zmax=ZMAX           max redshift [0.1]
#   --decmin=DECMIN       min declinaison [-30]
#   --decmax=DECMAX       max declinaison [90]
#   --ndet=NDET           required number of detections [1]
#   --ntransient=NTRANSIENT
#                         number of transientor [11]
#   --seed=SEED           seed [70]
#   --threshold=THRESHOLD
#                         S/N requirement for detection [1]

# %%
# !python /Users/manon/ztf_stage/script/run_simulation.py --folder_dir ZTF/data --ntransient 3500 --DataFile data_simu_nb.hdf5 --MetaFile meta_simu_nb.hdf5
# Out:
# <simsurvey.simulsurvey.SimulSurvey object at 0x7ff53dbd8c40>
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# /Users/manon/ZTF/simsurvey/simsurvey/simulsurvey.py:1577: RuntimeWarning: invalid value encountered in true_divide
#   mask_det = lc['flux']/lc['fluxerr'] > thr
# progress_bar_succes
# lc is not an astropy.table.table.Table type <class 'simsurvey.simulsurvey.LightcurveCollection'>
# meta data OrderedDict([('directory', 'dataLC'), ('file_name', 'dataLC/meta_simu_nb.hdf5')])          z                   t0         ... idx_orig   path
# -------------------- ------------------ ... -------- -------
#  0.09665627314283415  58168.04293368102 ...        3    SN_0
#  0.06768985090609805  58249.37422072563 ...        4    SN_1
# 0.052395678566137256 58236.173004001204 ...        5    SN_2
#  0.09496615230696706  58311.20197489228 ...        6    SN_3
#  0.07527202479792483  58421.07953363119 ...        7    SN_4
#  0.07864194667329098 58334.909398505326 ...        8    SN_5
#  0.07636610797218073  58346.25393644017 ...        9    SN_6
#                  ...                ... ...      ...     ...
#   0.0855217032228962 58395.906864462166 ...     3339 bad_138
#  0.09425598751029587  58287.48567803843 ...     3352 bad_139
#  0.08438140141648048 58512.972083539644 ...     3397 bad_140
#  0.06340675340833549  58487.34725507669 ...     3408 bad_141
#   0.0788320249555483  58500.75920264226 ...     3420 bad_142
#  0.08236868032236996 58192.989331830366 ...     3451 bad_143
#  0.08795611606186607  58294.70378302404 ...     3457 bad_144
# Length = 2775 rows
# End of LC simulation

# %%
# Read meta data file
class_meta = Read_LightCurve(file_name='meta_simu_nb.hdf5')
read_meta = class_meta.Read_file(path='meta')

read_meta.meta
# Out:
# OrderedDict([('directory', 'dataLC'),
#              ('file_name', 'dataLC/meta_simu_nb.hdf5')])

# %%
# Read the light curve data
class_data = Read_LightCurve(file_name='data_simu_nb.hdf5')
