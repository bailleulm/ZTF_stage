# %%
import sys
sys.path.append("/Users/manon/ztf_stage/python") #directory to your python class
sys.path.append("/Users/manon/ztf_stage/script") #directory to your python script
sys.path.append("/Users/manon/ztf_stage/csv") #directory to your csv file
sys.path.append("/Users/manon/ZTF/data") #directory to your data (from simsurvey)
sys.path.append("/Users/manon/ZTF") #directory to simsurvey_tools.py

# %%
from ztf_hdf5 import Write_LightCurve, Read_LightCurve, Plot_LightCurve
import csv
from astropy.table import Table
import os
import numpy as np
import operator
from astropy.table import QTable, Table, Column, vstack
import astropy

# %%
# Read meta data file
class_meta = Read_LightCurve(file_name='meta_simu.hdf5', inputDir='ZTF/dataLC')
read_meta = class_meta.Read_file(path='meta')

#read_meta

# %%
# Read the csv file with your selection

home_dir = os.environ.get('HOME')
folder_dir = os.path.join(home_dir, 'dataLC/selection_tab.csv')
folder_dir_seuil = os.path.join(home_dir, 'dataLC/seuil_name_selec.csv')

table = Table.read(folder_dir) #Lecture du fichier csv
table_2 = Table.read(folder_dir_seuil) #Lecture du fichier csv

#print(table,'\n\n', table_2)

# %% [markdown]
# # Adding len of different table in function of the different selection on the table of meta data

# %%
import operator
def selec_phase(Tab, csvFile, limSNR, selec=False, Verbose=False, Plot=False):
    
    SNR = Tab['flux'] / Tab['fluxerr']
    phase = (Tab['time'] - Tab.meta['t0']) / (1-Tab.meta['z'])
    Tab.add_columns([SNR, phase], names=['SNR', 'phase'])
    mask_SNR = Tab['SNR'] >= limSNR
    Tab = Tab[mask_SNR]
    len_tab = []
    
    for i, cols in enumerate(csvFile):
        if cols['col'] not in Tab.colnames:
            print(cols['col'], 'This column doesnt exist') 
    
        else:
            col = cols['col']
            op = eval(cols['op1'])
            type_ = eval(cols['type'])
            lim = type_(cols['lim_col'])
    
            mask = op(Tab[col], lim)
            new_Tab = Tab[mask]
        
            len_tab.append(len(new_Tab))
            
    if Verbose:
        print('min :', np.min(Tab['phase']), 'max :', np.max(Tab['phase']))
    if Plot:
        x = Tab['phase']
        y = Tab['flux']

        fig, axs = plt.subplots(1, 1, figsize=(10,8))
        axs.plot(x,y,marker = '*')
            
    if selec:
        return Tab
    else:
        return len_tab

# %%
clas2 = Read_LightCurve(file_name='data_simu.hdf5', inputDir='ZTF/dataLC')
read_data = clas2.Read_file(path='SN_0')

rtot = []
r = []
rb = table_2['name_selec']
for i, row in enumerate(read_meta):
    if row['path'] == 'SN_{}'.format(i):
        read_data = clas2.Read_file(path='SN_{}'.format(i))
        len_Tab = selec_phase(read_data, table, 5)
        r.append(len_Tab)
    else : 
        b = np.full((len(table_2)), -1)
        r.append(b.tolist())

rtot = np.array(r)

for i in range(0, len(rtot[0])):
    line = [row[i] for row in rtot]
    c = Column(line)
    read_meta.add_column(c, name=rb[i])
    read_meta = read_meta
    
read_meta
# Out:
# /var/folders/8n/j9hb298x4xq39l_vtv55kkp00000gp/T/ipykernel_83686/1317654429.py:4: RuntimeWarning: invalid value encountered in true_divide
#   SNR = Tab['flux'] / Tab['fluxerr']
# <Table length=398>
#          z                   t0                   x0           ... nb_band_ztfr nb_band_ztfg nb_band_ztfi
#       float64             float64              float64         ...    int64        int64        int64
# -------------------- ------------------ ---------------------- ... ------------ ------------ ------------
#  0.09746273114426751 58434.321856282484 0.00025622912210447927 ...            3            3            0
#  0.09545085017442173  58449.84672495065  0.0005428088482511581 ...            4            0            0
#  0.08329532832943781 58242.045208409225  0.0007019810069605971 ...            2            0            0
#  0.09665627314283415  58179.74313249251   0.000323846066201955 ...            1            0            0
#  0.06768985090609805 58285.001010193184  0.0010558214069944442 ...            7           15            0
# 0.052395678566137256  58440.57795955294  0.0018993318650067294 ...            3            1            0
#  0.09496615230696706  58404.34855619604  0.0004519889058892245 ...            0            0            0
#  0.07527202479792483  58262.54028992818  0.0007357072837832682 ...          185          128           11
#  0.07864194667329098  58400.65091764231  0.0004885173897171661 ...            8            1            0
#  0.07636610797218073  58282.01143462065  0.0004830939874074456 ...           30           24            2
#  0.06719229280005781 58318.941987158934  0.0009762864120534194 ...            4            4            0
# 0.034939255536784584 58396.281443945525   0.003887034248211899 ...            6            7            0
#  0.05647814437682584  58257.17361350978  0.0018158013482646564 ...           23           21            7
#  0.05704765622053076   58368.8558056228  0.0017825531713776771 ...           63           48            3
#  0.06697638013022884  58432.00611799869   0.001333785778576615 ...            5            1            0
#  0.09924158873036648  58237.51097948071  0.0002880869549254076 ...            0            0            0
#  0.09219572727853108 58293.477323718296   0.000533110264578684 ...            3            0            0
#  0.08745401984968042 58189.274203718385   0.000603120179497916 ...            0            2            0
#   0.0696175414329167  58352.30377607982  0.0006998440570666008 ...            0            0            0
#   0.0694164026092382 58495.892287140516  0.0004391971997558446 ...            0            1            0
#                  ...                ...                    ... ...          ...          ...          ...
#  0.07136242783320561  58510.98892255322  0.0011026473908375097 ...           -1           -1           -1
#  0.07014094123068594 58280.244622531296 0.00040335206182378545 ...           -1           -1           -1
#   0.0917091036094538  58451.56980362866  0.0005884340930662071 ...           -1           -1           -1
#  0.07643022348078693  58511.15375318513   0.001064179083036433 ...           -1           -1           -1
#   0.0981396432170374  58312.51786917714 0.00019223687050469763 ...           -1           -1           -1
#  0.06853345398738599  58487.25534347333  0.0006395039239427869 ...           -1           -1           -1
#  0.08043603426013846 58481.849046823074  0.0004851087018811351 ...           -1           -1           -1
#  0.09862951083733154 58192.183639703966 0.00018729435938656373 ...           -1           -1           -1
#  0.03397751328381627   58502.6530036212  0.0013417709126452542 ...           -1           -1           -1
#   0.0914949915177106 58501.579971650164  0.0003543689849107352 ...           -1           -1           -1
#  0.09358600212445542  58222.64479041944   0.000339803387702402 ...           -1           -1           -1
#  0.09165264361725992 58504.091710112945  0.0006508080048440881 ...           -1           -1           -1
#  0.09349713373287187  58471.63816120698 0.00038529000534350135 ...           -1           -1           -1
#  0.04993225740394547  58357.09787349076  0.0010159570979562942 ...           -1           -1           -1
#  0.06157526788478131  58312.60632104832  0.0009226769888808455 ...           -1           -1           -1
#  0.06537629030073816  58333.69052731417  0.0009908506346541113 ...           -1           -1           -1
#  0.07063923096832568  58223.35753542243  0.0005638387494870239 ...           -1           -1           -1
#  0.07758254414907863  58475.76163290115   0.001014500798851094 ...           -1           -1           -1
#   0.0822084136308263 58347.107963293296  0.0007098808307563223 ...           -1           -1           -1
#    0.095528749705609  58502.10412591921  0.0005013609411205552 ...           -1           -1           -1
#  0.09296467537377794 58411.269120796176  0.0005615105190429029 ...           -1           -1           -1

# %% [markdown]
# # We apply our selection criteria

# %%
def selec(list_lenTable, csvFile):
    
    res = 1
    len_table = []
    
    for i, len_selec in enumerate(list_lenTable):
        if res:
            res &= operator.ge(len_selec, csvFile['seuil'][i])
        if not res:
            break
            
    return res

# %%
R, sel_list = [], []

for i, path in enumerate(read_meta['path']):
    class_data = Read_LightCurve(file_name='data_simu.hdf5', inputDir='ZTF/dataLC')
    if path == 'SN_{}'.format(i):
        lc = class_data.Read_file(path=path)
        lc_len = selec_phase(lc, table, 5, selec=False)
        sel = selec(lc_len, table_2)
        R.append(sel)
    else:
        R.append(0)

pass_selec = Column(R)

if 'pass selec' in read_meta.colnames:
    read_meta['pass selec'] = pass_selec
else :
    read_meta.add_column(pass_selec, name = 'pass selec')
    
read_meta
# Out:
# /var/folders/8n/j9hb298x4xq39l_vtv55kkp00000gp/T/ipykernel_83686/1317654429.py:4: RuntimeWarning: invalid value encountered in true_divide
#   SNR = Tab['flux'] / Tab['fluxerr']
# <Table length=398>
#          z                   t0                   x0           ... nb_band_ztfg nb_band_ztfi pass selec
#       float64             float64              float64         ...    int64        int64       int64
# -------------------- ------------------ ---------------------- ... ------------ ------------ ----------
#  0.09746273114426751 58434.321856282484 0.00025622912210447927 ...            3            0          0
#  0.09545085017442173  58449.84672495065  0.0005428088482511581 ...            0            0          0
#  0.08329532832943781 58242.045208409225  0.0007019810069605971 ...            0            0          0
#  0.09665627314283415  58179.74313249251   0.000323846066201955 ...            0            0          0
#  0.06768985090609805 58285.001010193184  0.0010558214069944442 ...           15            0          0
# 0.052395678566137256  58440.57795955294  0.0018993318650067294 ...            1            0          0
#  0.09496615230696706  58404.34855619604  0.0004519889058892245 ...            0            0          0
#  0.07527202479792483  58262.54028992818  0.0007357072837832682 ...          128           11          1
#  0.07864194667329098  58400.65091764231  0.0004885173897171661 ...            1            0          0
#  0.07636610797218073  58282.01143462065  0.0004830939874074456 ...           24            2          1
#  0.06719229280005781 58318.941987158934  0.0009762864120534194 ...            4            0          0
# 0.034939255536784584 58396.281443945525   0.003887034248211899 ...            7            0          0
#  0.05647814437682584  58257.17361350978  0.0018158013482646564 ...           21            7          1
#  0.05704765622053076   58368.8558056228  0.0017825531713776771 ...           48            3          1
#  0.06697638013022884  58432.00611799869   0.001333785778576615 ...            1            0          0
#  0.09924158873036648  58237.51097948071  0.0002880869549254076 ...            0            0          0
#  0.09219572727853108 58293.477323718296   0.000533110264578684 ...            0            0          0
#  0.08745401984968042 58189.274203718385   0.000603120179497916 ...            2            0          0
#   0.0696175414329167  58352.30377607982  0.0006998440570666008 ...            0            0          0
#   0.0694164026092382 58495.892287140516  0.0004391971997558446 ...            1            0          0
#                  ...                ...                    ... ...          ...          ...        ...
#  0.07136242783320561  58510.98892255322  0.0011026473908375097 ...           -1           -1          0
#  0.07014094123068594 58280.244622531296 0.00040335206182378545 ...           -1           -1          0
#   0.0917091036094538  58451.56980362866  0.0005884340930662071 ...           -1           -1          0
#  0.07643022348078693  58511.15375318513   0.001064179083036433 ...           -1           -1          0
#   0.0981396432170374  58312.51786917714 0.00019223687050469763 ...           -1           -1          0
#  0.06853345398738599  58487.25534347333  0.0006395039239427869 ...           -1           -1          0
#  0.08043603426013846 58481.849046823074  0.0004851087018811351 ...           -1           -1          0
#  0.09862951083733154 58192.183639703966 0.00018729435938656373 ...           -1           -1          0
#  0.03397751328381627   58502.6530036212  0.0013417709126452542 ...           -1           -1          0
#   0.0914949915177106 58501.579971650164  0.0003543689849107352 ...           -1           -1          0
#  0.09358600212445542  58222.64479041944   0.000339803387702402 ...           -1           -1          0
#  0.09165264361725992 58504.091710112945  0.0006508080048440881 ...           -1           -1          0
#  0.09349713373287187  58471.63816120698 0.00038529000534350135 ...           -1           -1          0
#  0.04993225740394547  58357.09787349076  0.0010159570979562942 ...           -1           -1          0
#  0.06157526788478131  58312.60632104832  0.0009226769888808455 ...           -1           -1          0
#  0.06537629030073816  58333.69052731417  0.0009908506346541113 ...           -1           -1          0
#  0.07063923096832568  58223.35753542243  0.0005638387494870239 ...           -1           -1          0
#  0.07758254414907863  58475.76163290115   0.001014500798851094 ...           -1           -1          0
#   0.0822084136308263 58347.107963293296  0.0007098808307563223 ...           -1           -1          0
#    0.095528749705609  58502.10412591921  0.0005013609411205552 ...           -1           -1          0
#  0.09296467537377794 58411.269120796176  0.0005615105190429029 ...           -1           -1          0

# %%
if os.path.isfile('/Users/manon/ZTF/dataLC/meta_selected.hdf5'):
    print('File already exist : file remove')
    os.remove('/Users/manon/ZTF/dataLC/meta_selected.hdf5')
else:
    print('')
    
astropy.io.misc.hdf5.write_table_hdf5(read_meta, '/Users/manon/ZTF/dataLC/meta_selected.hdf5', path='meta', append=True,
                                                  overwrite=True, serialize_meta=False)
# Out:
# File already exist : file remove
# WARNING: Attribute `__serialized_columns__` of type <class 'dict'> cannot be written to HDF5 files - skipping. (Consider specifying serialize_meta=True to write all meta data) [astropy.io.misc.hdf5]

# %%
class_meta = Read_LightCurve(file_name='meta_selected.hdf5', inputDir='ZTF/dataLC')
new_read_meta = class_meta.Read_file(path='meta')
new_read_meta
# Out:
# <Table length=398>
#          z                   t0                   x0           ... nb_band_ztfg nb_band_ztfi pass selec
#       float64             float64              float64         ...    int64        int64       int64
# -------------------- ------------------ ---------------------- ... ------------ ------------ ----------
#  0.09746273114426751 58434.321856282484 0.00025622912210447927 ...            3            0          0
#  0.09545085017442173  58449.84672495065  0.0005428088482511581 ...            0            0          0
#  0.08329532832943781 58242.045208409225  0.0007019810069605971 ...            0            0          0
#  0.09665627314283415  58179.74313249251   0.000323846066201955 ...            0            0          0
#  0.06768985090609805 58285.001010193184  0.0010558214069944442 ...           15            0          0
# 0.052395678566137256  58440.57795955294  0.0018993318650067294 ...            1            0          0
#  0.09496615230696706  58404.34855619604  0.0004519889058892245 ...            0            0          0
#  0.07527202479792483  58262.54028992818  0.0007357072837832682 ...          128           11          1
#  0.07864194667329098  58400.65091764231  0.0004885173897171661 ...            1            0          0
#  0.07636610797218073  58282.01143462065  0.0004830939874074456 ...           24            2          1
#  0.06719229280005781 58318.941987158934  0.0009762864120534194 ...            4            0          0
# 0.034939255536784584 58396.281443945525   0.003887034248211899 ...            7            0          0
#  0.05647814437682584  58257.17361350978  0.0018158013482646564 ...           21            7          1
#  0.05704765622053076   58368.8558056228  0.0017825531713776771 ...           48            3          1
#  0.06697638013022884  58432.00611799869   0.001333785778576615 ...            1            0          0
#  0.09924158873036648  58237.51097948071  0.0002880869549254076 ...            0            0          0
#  0.09219572727853108 58293.477323718296   0.000533110264578684 ...            0            0          0
#  0.08745401984968042 58189.274203718385   0.000603120179497916 ...            2            0          0
#   0.0696175414329167  58352.30377607982  0.0006998440570666008 ...            0            0          0
#   0.0694164026092382 58495.892287140516  0.0004391971997558446 ...            1            0          0
#                  ...                ...                    ... ...          ...          ...        ...
#  0.07136242783320561  58510.98892255322  0.0011026473908375097 ...           -1           -1          0
#  0.07014094123068594 58280.244622531296 0.00040335206182378545 ...           -1           -1          0
#   0.0917091036094538  58451.56980362866  0.0005884340930662071 ...           -1           -1          0
#  0.07643022348078693  58511.15375318513   0.001064179083036433 ...           -1           -1          0
#   0.0981396432170374  58312.51786917714 0.00019223687050469763 ...           -1           -1          0
#  0.06853345398738599  58487.25534347333  0.0006395039239427869 ...           -1           -1          0
#  0.08043603426013846 58481.849046823074  0.0004851087018811351 ...           -1           -1          0
#  0.09862951083733154 58192.183639703966 0.00018729435938656373 ...           -1           -1          0
#  0.03397751328381627   58502.6530036212  0.0013417709126452542 ...           -1           -1          0
#   0.0914949915177106 58501.579971650164  0.0003543689849107352 ...           -1           -1          0
#  0.09358600212445542  58222.64479041944   0.000339803387702402 ...           -1           -1          0
#  0.09165264361725992 58504.091710112945  0.0006508080048440881 ...           -1           -1          0
#  0.09349713373287187  58471.63816120698 0.00038529000534350135 ...           -1           -1          0
#  0.04993225740394547  58357.09787349076  0.0010159570979562942 ...           -1           -1          0
#  0.06157526788478131  58312.60632104832  0.0009226769888808455 ...           -1           -1          0
#  0.06537629030073816  58333.69052731417  0.0009908506346541113 ...           -1           -1          0
#  0.07063923096832568  58223.35753542243  0.0005638387494870239 ...           -1           -1          0
#  0.07758254414907863  58475.76163290115   0.001014500798851094 ...           -1           -1          0
#   0.0822084136308263 58347.107963293296  0.0007098808307563223 ...           -1           -1          0
#    0.095528749705609  58502.10412591921  0.0005013609411205552 ...           -1           -1          0
#  0.09296467537377794 58411.269120796176  0.0005615105190429029 ...           -1           -1          0
